# %% [markdown]
# Create csv's for orbital data of Mercury, Venus, Earth, Mars

# %% [markdown]
# # Mercury

# %%
import csv

# Define the input and output file names
input_file = 'horizons_mercury.txt'
output_file = 'ephemeris_mercury.csv'

# Open the input file and read the lines
with open(input_file, 'r') as file:
    lines = file.readlines()

# %%
# Identify the start and end of the data section
start_idx = None
end_idx = None

for idx, line in enumerate(lines):
    if line.startswith('$$SOE'):
        start_idx = idx + 1
    elif line.startswith('$$EOE'):
        end_idx = idx
        break

# Extract the data section
data_lines = lines[start_idx:end_idx]

# %%
# Define the column headers (adjust as needed based on the data)
headers = ["JDTDB", "Date", "Me_X", "Me_Y", "Me_Z", "Me_VX", "Me_VY", "Me_VZ", "LT", "RG", "RR"]

# %%
# Write the data to a CSV file
with open(output_file, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(headers)  # Write the header row
    for line in data_lines:
        # Split the line into columns (adjust the delimiter as needed)
        columns = line.split(",")
        # Write the columns to the CSV file
        csvwriter.writerow(columns)

# %% [markdown]
# # Venus

# %%
import csv

# Define the input and output file names
input_file = 'horizons_venus.txt'
output_file = 'ephemeris_venus.csv'

# Open the input file and read the lines
with open(input_file, 'r') as file:
    lines = file.readlines()

# %%
# Identify the start and end of the data section
start_idx = None
end_idx = None

for idx, line in enumerate(lines):
    if line.startswith('$$SOE'):
        start_idx = idx + 1
    elif line.startswith('$$EOE'):
        end_idx = idx
        break

# Extract the data section
data_lines = lines[start_idx:end_idx]

# %%
# Define the column headers (adjust as needed based on the data)
headers = ["JDTDB", "Date", "Ve_X", "Ve_Y", "Ve_Z", "Ve_VX", "Ve_VY", "Ve_VZ", "LT", "RG", "RR"]

# %%
# Write the data to a CSV file
with open(output_file, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(headers)  # Write the header row
    for line in data_lines:
        # Split the line into columns (adjust the delimiter as needed)
        columns = line.split(",")
        # Write the columns to the CSV file
        csvwriter.writerow(columns)

# %% [markdown]
# # Earth

# %%
import csv

# Define the input and output file names
input_file = 'horizons_earth.txt'
output_file = 'ephemeris_earth.csv'

# Open the input file and read the lines
with open(input_file, 'r') as file:
    lines = file.readlines()

# %%
# Identify the start and end of the data section
start_idx = None
end_idx = None

for idx, line in enumerate(lines):
    if line.startswith('$$SOE'):
        start_idx = idx + 1
    elif line.startswith('$$EOE'):
        end_idx = idx
        break

# Extract the data section
data_lines = lines[start_idx:end_idx]

# %%
# Define the column headers (adjust as needed based on the data)
headers = ["JDTDB", "Date", "Ea_X", "Ea_Y", "Ea_Z", "Ea_VX", "Ea_VY", "Ea_VZ", "LT", "RG", "RR"]

# %%
# Write the data to a CSV file
with open(output_file, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(headers)  # Write the header row
    for line in data_lines:
        # Split the line into columns (adjust the delimiter as needed)
        columns = line.split(",")
        # Write the columns to the CSV file
        csvwriter.writerow(columns)

# %% [markdown]
# # Mars

# %%
import csv

# Define the input and output file names
input_file = 'horizons_mars.txt'
output_file = 'ephemeris_mars.csv'

# Open the input file and read the lines
with open(input_file, 'r') as file:
    lines = file.readlines()

# %%
# Identify the start and end of the data section
start_idx = None
end_idx = None

for idx, line in enumerate(lines):
    if line.startswith('$$SOE'):
        start_idx = idx + 1
    elif line.startswith('$$EOE'):
        end_idx = idx
        break

# Extract the data section
data_lines = lines[start_idx:end_idx]

# %%
# Define the column headers (adjust as needed based on the data)
headers = ["JDTDB", "Date", "Ma_X", "Ma_Y", "Ma_Z", "Ma_VX", "Ma_VY", "Ma_VZ", "LT", "RG", "RR"]

# %%
# Write the data to a CSV file
with open(output_file, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(headers)  # Write the header row
    for line in data_lines:
        # Split the line into columns (adjust the delimiter as needed)
        columns = line.split(",")
        # Write the columns to the CSV file
        csvwriter.writerow(columns)
