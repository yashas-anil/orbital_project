# %% [markdown]
# ## Prototype Orbital Model
#
# Predicting the velocity of Mars (VX,VY,VZ) based on its position coordinates (X,Y,Z)

# %%
import numpy
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
eph_df=pd.read_csv('ephemeris.csv', index_col=False)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_29292\4238620832.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   eph_df=pd.read_csv('ephemeris.csv', index_col=False)

# %%
X=eph_df[['X','Y','Z']].values
y=eph_df[['VX','VY','VZ']].values
X
# Out:
# array([[-1.18076388e+08, -1.95940123e+08, -1.19448380e+06],
#        [-1.16197554e+08, -1.96831696e+08, -1.25941397e+06],
#        [-1.14309085e+08, -1.97706893e+08, -1.32423851e+06],
#        ...,
#        [-7.31743786e+07,  2.28864604e+08,  6.61162179e+06],
#        [-7.50883462e+07,  2.28405018e+08,  6.64894964e+06],
#        [-7.69970556e+07,  2.27929208e+08,  6.68580843e+06]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
len(y_test)
# Out:
# 5480

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model=Sequential()
model.add(Dense(6, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(3))
model.compile(optimizer='rmsprop',loss='mse')

# %%
model.fit(x=X_train,y=y_train,epochs=50)
# Out:
# Epoch 1/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 189.8649
# Epoch 2/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 160.1857
# Epoch 3/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 110.9460
# Epoch 4/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 62.6493
# Epoch 5/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27.0349
# Epoch 6/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 2.9493
# Epoch 7/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4464
# Epoch 8/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4384
# Epoch 9/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.4373
# Epoch 10/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4362
# Epoch 11/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4358
# Epoch 12/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.4358
# Epoch 13/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4370
# Epoch 14/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4373
# Epoch 15/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.4376
# Epoch 16/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4362
# Epoch 17/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4375
# Epoch 18/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4347
# Epoch 19/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4377
# Epoch 20/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.4374
# Epoch 21/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.4372
# Epoch 22/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.4362
# Epoch 23/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 0.4351
# Epoch 24/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4366
# Epoch 25/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.4359
# Epoch 26/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 0.4376
# Epoch 27/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 0.4353
# Epoch 28/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.4357
# Epoch 29/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.4360
# Epoch 30/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.4349
# Epoch 31/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4368
# Epoch 32/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.4375
# Epoch 33/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.4359
# Epoch 34/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.4351
# Epoch 35/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 0.4368
# Epoch 36/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.4368
# Epoch 37/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.4362
# Epoch 38/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4362
# Epoch 39/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.4366
# Epoch 40/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 0.4375
# Epoch 41/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.4368
# Epoch 42/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 0.4366
# Epoch 43/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4364
# Epoch 44/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.4360
# Epoch 45/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.4357
# Epoch 46/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.4352
# Epoch 47/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 0.4359
# Epoch 48/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 0.4373
# Epoch 49/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.4360
# Epoch 50/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4351

# %%
test_pred=model.predict(X_test)
test_pred
test_pred=pd.DataFrame(test_pred.reshape(5480,3))
# note you may need to adjust the reshape parameter based on the size of the training set
pred_df=pd.DataFrame(y_test)
pred_df=pd.concat([pred_df,test_pred],axis=1)
pred_df.columns=['True VX','True VY','True VZ','Predicted VX','Predicted VY','Predicted VZ']
pred_df
# Out:
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#         True VX    True VY   True VZ  Predicted VX  Predicted VY  Predicted VZ
# 0     23.808888  10.021354 -0.373616     22.911335     10.181625     -0.370717
# 1     12.666947 -19.113332 -0.711843     13.935427    -19.215433     -0.767230
# 2     25.164580   2.134370 -0.575137     24.684639      3.047426     -0.562795
# 3     12.623895 -19.143789 -0.711918     13.867727    -19.188765     -0.765052
# 4     18.773869  18.433595 -0.074098     17.802240     17.809938     -0.089363
# ...         ...        ...       ...           ...           ...           ...
# 5475  -3.630844  25.873454  0.630968     -2.630229     25.028761      0.551021
# 5476   6.088567 -21.619006 -0.602187      7.107030    -22.418428     -0.670082
# 5477 -22.357283   8.732495  0.732756    -21.686621      9.634302      0.687682
# 5478  -9.126248 -20.001148 -0.194085     -9.447546    -20.937281     -0.242116
# 5479  25.151102   1.925698 -0.577551     24.706396      2.671593     -0.570071
#
# [5480 rows x 6 columns]

# %%
model.evaluate(X_test, y_test)
# Out:
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4499
# 0.44550955295562744
